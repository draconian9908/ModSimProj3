# %% [markdown]
# # Flying Mantines
#
# ModSim Project 3
#
# Lydia Hodges and Chase Joyner
#
# License: [Creative Commons Attribution 4.0 International](https://creativecommons.org/licenses/by/4.0)

# %%
# %matplotlib inline

from modsim import *

# %%
m = UNITS.meter
s = UNITS.second
kg = UNITS.kilogram
degree = UNITS.degree
radian = UNITS.radian

# %%
angle = 90 * degree

condition_m = Condition(x = 0 * m, 
                      y = 0 * m,
                      g = 9.8 * m/s**2,
                      diameter = 6.7 * m,
                      mass = 1350 * kg,
                      rho = 1.2 * kg/m**3,
                      angle = angle,
                      den = 1000 * kg/m**3,
                      C_d = 1.28 * np.sin(np.deg2rad(angle)),
                      C_l = 2 * np.pi * np.deg2rad(angle),
                      wing_area = 14.14 * m**2,
                      velocity = 9.83 * m / s,
                      bh = 4.9 * m,
                      duration = 1 * s)
angle_array = linrange(60, 90, 1)

# %%
condition_p = Condition(x = 14 * m,
                        y = 4.9 * m,
                        velocity = -11.18 * m/s,
                        mass = 70 * kg,
                        angle = 0 * degree,
                        density = 985 * kg/m**2,
                        duration = 1 * s,
                        diameter = 0.18 * m)

# %%
def make_system(condition):
    
    unpack(condition)
    
    # convert angle to degrees
    theta = np.deg2rad(angle)
    
    # compute x and y components of velocity
    vx, vy = pol2cart(theta, velocity)
    
    # make the initial state
    init = State(x=x, y=y, vx=vx, vy=vy)
    
    # compute area from diameter
    area = np.pi * (diameter/2)**2
    
    # compute timestamps
    ts = linspace(0, duration, 101)
    
    return System(init=init, g=g, mass=mass, 
                  area=area, rho=rho, C_d=C_d, ts=ts)

# %%
system = make_system(condition_m)
system_2 = make_system(condition_p)

# %%
def slope_func_p(state, t, system):
    
    x, y, vx, vy = state
    unpack(system)
    
    a_grav = Vector(0, -g)

    v = Vector(vx, vy)
    
    ax = 0 * m**2
    ay = 0 * m**2
    
    return vx, vy, ax, ay

# %%
slope_func_p(system_2.init, 0, system_2)
# Out:
# (<Quantity(-11.18, 'meter / second')>,
#  <Quantity(-0.0, 'meter / second')>,
#  <Quantity(0, 'meter ** 2')>,
#  <Quantity(0, 'meter ** 2')>)

# %%
run_odeint(system_2, slope_func_p)
print(system_2.results)
# Out:
#             x    y     vx   vy
# 0.00  14.0000  4.9 -11.18 -0.0
# 0.01  13.8882  4.9 -11.18  0.0
# 0.02  13.7764  4.9 -11.18  0.0
# 0.03  13.6646  4.9 -11.18  0.0
# 0.04  13.5528  4.9 -11.18  0.0
# 0.05  13.4410  4.9 -11.18  0.0
# 0.06  13.3292  4.9 -11.18  0.0
# 0.07  13.2174  4.9 -11.18  0.0
# 0.08  13.1056  4.9 -11.18  0.0
# 0.09  12.9938  4.9 -11.18  0.0
# 0.10  12.8820  4.9 -11.18  0.0
# 0.11  12.7702  4.9 -11.18  0.0
# 0.12  12.6584  4.9 -11.18  0.0
# 0.13  12.5466  4.9 -11.18  0.0
# 0.14  12.4348  4.9 -11.18  0.0
# 0.15  12.3230  4.9 -11.18  0.0
# 0.16  12.2112  4.9 -11.18  0.0
# 0.17  12.0994  4.9 -11.18  0.0
# 0.18  11.9876  4.9 -11.18  0.0
# 0.19  11.8758  4.9 -11.18  0.0
# 0.20  11.7640  4.9 -11.18  0.0
# 0.21  11.6522  4.9 -11.18  0.0
# 0.22  11.5404  4.9 -11.18  0.0
# 0.23  11.4286  4.9 -11.18  0.0
# 0.24  11.3168  4.9 -11.18  0.0
# 0.25  11.2050  4.9 -11.18  0.0
# 0.26  11.0932  4.9 -11.18  0.0
# 0.27  10.9814  4.9 -11.18  0.0
# 0.28  10.8696  4.9 -11.18  0.0
# 0.29  10.7578  4.9 -11.18  0.0
# ...       ...  ...    ...  ...
# 0.71   6.0622  4.9 -11.18  0.0
# 0.72   5.9504  4.9 -11.18  0.0
# 0.73   5.8386  4.9 -11.18  0.0
# 0.74   5.7268  4.9 -11.18  0.0
# 0.75   5.6150  4.9 -11.18  0.0
# 0.76   5.5032  4.9 -11.18  0.0
# 0.77   5.3914  4.9 -11.18  0.0
# 0.78   5.2796  4.9 -11.18  0.0
# 0.79   5.1678  4.9 -11.18  0.0
# 0.80   5.0560  4.9 -11.18  0.0
# 0.81   4.9442  4.9 -11.18  0.0
# 0.82   4.8324  4.9 -11.18  0.0
# 0.83   4.7206  4.9 -11.18  0.0
# 0.84   4.6088  4.9 -11.18  0.0
# 0.85   4.4970  4.9 -11.18  0.0
# 0.86   4.3852  4.9 -11.18  0.0
# 0.87   4.2734  4.9 -11.18  0.0
# 0.88   4.1616  4.9 -11.18  0.0
# 0.89   4.0498  4.9 -11.18  0.0
# 0.90   3.9380  4.9 -11.18  0.0
# 0.91   3.8262  4.9 -11.18  0.0
# 0.92   3.7144  4.9 -11.18  0.0
# 0.93   3.6026  4.9 -11.18  0.0
# 0.94   3.4908  4.9 -11.18  0.0
# 0.95   3.3790  4.9 -11.18  0.0
# 0.96   3.2672  4.9 -11.18  0.0
# 0.97   3.1554  4.9 -11.18  0.0
# 0.98   3.0436  4.9 -11.18  0.0
# 0.99   2.9318  4.9 -11.18  0.0
# 1.00   2.8200  4.9 -11.18  0.0
#
# [101 rows x 4 columns]

# %%
def slope_func_m(state, t, system):
    
    x, y, vx, vy = state
    unpack(system)
    
    a_grav = Vector(0, -g)

    v = Vector(vx, vy)
    
    f_drag = -C_d * wing_area * rho * (v**2 / 2)
    a_drag = f_drag / mass
    
    f_lift = C_l * wing_area * rho * (v**2 / 2)
    a_lift = f_lift / mass
    
    a = a_grav + a_drag + a_lift
    
    #print(mass, C_l, a_lift, C_d, a_drag)
    
    return vx, vy, a.x, a.y

# %%
slope_func_m(system.init, 0, system)
# 0.79  4.755120e-16  5.905807  6.019139e-16  4.570382
# 0.80  4.815311e-16  5.951077  6.019139e-16  4.483444
# 0.81  4.875503e-16  5.995475  6.019139e-16  4.396085
# 0.82  4.935694e-16  6.038997  6.019139e-16  4.308311
# 0.83  4.995885e-16  6.081640  6.019139e-16  4.220127
# 0.84  5.056077e-16  6.123398  6.019139e-16  4.131540
# 0.85  5.116268e-16  6.164269  6.019139e-16  4.042558
# 0.86  5.176460e-16  6.204248  6.019139e-16  3.953186
# 0.87  5.236651e-16  6.243332  6.019139e-16  3.863432
# 0.88  5.296842e-16  6.281516  6.019139e-16  3.773303
# 0.89  5.357034e-16  6.318797  6.019139e-16  3.682806
# 0.90  5.417225e-16  6.355171  6.019139e-16  3.591948
# 0.91  5.477417e-16  6.390634  6.019139e-16  3.500738
# 0.92  5.537608e-16  6.425184  6.019139e-16  3.409182
# 0.93  5.597799e-16  6.458817  6.019139e-16  3.317288
# 0.94  5.657991e-16  6.491529  6.019139e-16  3.225065
# 0.95  5.718182e-16  6.523317  6.019139e-16  3.132520
# 0.96  5.778373e-16  6.554178  6.019139e-16  3.039662
# 0.97  5.838565e-16  6.584109  6.019139e-16  2.946498
# 0.98  5.898756e-16  6.613107  6.019139e-16  2.853038
# 0.99  5.958948e-16  6.641169  6.019139e-16  2.759289
# 1.00  6.019139e-16  6.668292  6.019139e-16  2.665260
#
# [101 rows x 4 columns]

# %%
xs = system.results.x
ys = system.results.y
newfig()
plot(xs, ys, label='trajectory')
decorate(xlabel='x position (m)',
         ylabel='y position (m)',
        title='Single Run Through (Angle 60)')
savefig('Proj3_SingleRun.pdf')
# Out:
# Saving figure to file Proj3_SingleRun.pdf

# %%
def sweep_param(angle_array, system):
    newfig()
    decorate(xlabel='x position (m)',
             ylabel='y position (m)',
            title='Sweep Angle (60 - 90)',)
    for ang in angle_array:
        condition_m.set(angle=ang)
        system = make_system(condition_m)
        run_odeint(system, slope_func_m)
        xs = system.results.x
        ys = system.results.y
        plot(xs, ys)
    savefig('Proj3_SweepAngle.pdf')

# %%
sweep_param(angle_array, system)
# Out:
# C:\ProgramData\Miniconda3\lib\site-packages\matplotlib\axes\_axes.py:545: UserWarning: No labelled objects found. Use label='...' kwarg on individual plots.
#   warnings.warn("No labelled objects found. "
# Saving figure to file Proj3_SweepAngle.pdf

# %%
def run_sim(state, system):
    
    run_odeint(system, slope_func_m)
    h = system.results.y.loc(1.5)
    f = slope_func_m(system.init, h, system)
    acc = sqrt((f.a.x)**2 + (f.a.y)**2)
    force = mass * acc
    print(force)

# %%
run_sim(system.init, system)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-93-72d08e3b6564> in <module>()
# ----> 1 run_sim(system.init, system)
#
# <ipython-input-92-eb8b163f5a3c> in run_sim(state, system)
#       4     h = system.results.y.loc(1.5)
#       5     f = slope_func(system.init, h, system)
# ----> 6     acc = sqrt((f.a.x)**2 + (f.a.y)**2)
#       7     force = mass * acc
#       8     print(force)
#
# AttributeError: 'tuple' object has no attribute 'a'
